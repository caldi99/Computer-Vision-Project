# %% [markdown]
# # TRAIN CNN NOTEBOOK
#
# In order to be able to execute properly this notebook it is suggested if you enable the GPU acceleration. To do so, click on the Runtime/Change type of runtime, and select GPU and finally save.
# Discalimer : Remember to do this step **before** proceding further
#
# This notebook was entirely produced by Francesco Caldivezzi

# %% [markdown]
# ## MOUNT GOOGLE DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## UNZIP DATASET

# %%
# !cp drive/MyDrive/CV/dataset.zip dataset.zip
# !mkdir dataset
# !unzip --qq dataset.zip -d /content/dataset/ 
# !rm dataset.zip

# %% [markdown]
# ## FINE TUNE THE CNN
#
# In order to fine tune the CNN, you need as said in the README.MD file, to upload the following folders/files (in the root of this enviroment) :
#
# - python_scripts/fine_tune_cnn.py (file)
# - python_scripts/config/ (folder and its content)
#
# Notice that, to upload the directory "python_scripts/config/" you need first to create it (rigth click on the the enviroment root and then "New Folder") and then upload what is inside
#
# After, this you can run the below cell and finally when the execution has finished you can download the "model.h5" file if you want
#
# *The below cell will take a while, so take a break and drink a coffee*

# %%
# !python fine_tune_cnn.py
# Out:
# Found 42398 images belonging to 2 classes.
# Found 14134 images belonging to 2 classes.
# Found 6280 images belonging to 2 classes.
# DEFINE MODEL
# 2022-06-23 16:22:43.140475: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# START TRAINING
# Epoch 1/5
# 1324/1324 [==============================] - 532s 397ms/step - loss: 0.1076 - accuracy: 0.9598 - val_loss: 0.0462 - val_accuracy: 0.9827
# Epoch 2/5
# 1324/1324 [==============================] - 520s 393ms/step - loss: 0.0570 - accuracy: 0.9789 - val_loss: 0.0388 - val_accuracy: 0.9863
# Epoch 3/5
# 1324/1324 [==============================] - 523s 395ms/step - loss: 0.0510 - accuracy: 0.9809 - val_loss: 0.0355 - val_accuracy: 0.9864
# Epoch 4/5
# 1324/1324 [==============================] - 526s 398ms/step - loss: 0.0452 - accuracy: 0.9837 - val_loss: 0.0344 - val_accuracy: 0.9876
# ...

# %% [markdown]
# ## CONVERT MODEL FROM .h5 FORMAT TO .pb FORMAT IN ORDER TO USE IT WITH OPENCV
#
# Before executing this cell, make sure as said in the README.MD file, to upload, in the root of the colab enviroment, if not already present the "model.h5" file and the following other two things :
# - python_scripts/convert_model_to_opencv.py (file)
# - Optional : python_scripts/config/ (folder and its content) (if not already done)

# %%
# !python convert_model_to_opencv.py
# Out:
# 2022-06-23 15:32:18.580785: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# FRONZEN LAYERS :
# --------------------------------------------------
# Frozen model layers:
# x
# model/conv1_pad/Pad/paddings
# model/conv1_pad/Pad
# model/conv1_conv/Conv2D/ReadVariableOp/resource
# model/conv1_conv/Conv2D/ReadVariableOp
# model/conv1_conv/Conv2D
# model/conv1_conv/BiasAdd/ReadVariableOp/resource
# model/conv1_conv/BiasAdd/ReadVariableOp
# model/conv1_conv/BiasAdd
# model/pool1_pad/Pad/paddings
# model/pool1_pad/Pad
# model/pool1_pool/MaxPool
# model/conv2_block1_preact_bn/ReadVariableOp/resource
# model/conv2_block1_preact_bn/ReadVariableOp
# model/conv2_block1_preact_bn/ReadVariableOp_1/resource
# model/conv2_block1_preact_bn/ReadVariableOp_1
# model/conv2_block1_preact_bn/FusedBatchNormV3/ReadVariableOp/resource
# ...
